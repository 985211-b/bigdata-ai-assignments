# %% [markdown]
# # 课程作业 ② 创建 .ipynb 并运行
#
# Notebook（`.ipynb`）能一边写代码一边看结果，是做数据分析、记录实验过程最常用的工具。
#
# - 单元格分两种：**Code**（写代码）和 **Markdown**（写说明文字）
# - 运行当前单元格：按 `Shift + Enter`
# - 运行全部：顶部工具栏的 ▶▶ 按钮

# %%
print('我也会写程序啦！')
# Out:
# 我也会写程序啦！

# %% [markdown]
# ## 小扩展：看看运行环境
#
# 下面的代码会打印出当前 Notebook 用的是哪个 Python。

# %%
import platform
import sys

print(f'Python 版本: {platform.python_version()}')
print(f'解释器路径: {sys.executable}')
# Out:
# Python 版本: 3.12.10
# 解释器路径: C:\Users\曾明香\AppData\Local\Programs\Python\Python312\python.exe

# %% [markdown]
# ## 小扩展：算个数
#
# 求 1 到 100 的和。

# %%
total = sum(range(1, 101))
print(f'1 到 100 的和 = {total}')
# Out:
# 1 到 100 的和 = 5050
